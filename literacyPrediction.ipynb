# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('Literacy_rate, adult_total(%_of people_ages_15_and_above).csv',skiprows=3)

df3 = df.iloc[:,4:]
display(df3.shape)
yempty = df3.iloc[4:5,].to_numpy()
df3.dropna(axis=0, how='all', thresh=5, inplace=True)
display(df3)
display(df3.shape)
# Out:
# (264, 61)
#      1960  1961  1962  1963  ...      2017      2018  2019  Unnamed: 64
# 3     NaN   NaN   NaN   NaN  ...       NaN  98.14115   NaN          NaN
# 5     NaN   NaN   NaN   NaN  ...  74.47393  74.59660   NaN          NaN
# 7     NaN   NaN   NaN   NaN  ...       NaN  99.00387   NaN          NaN
# 13    NaN   NaN   NaN   NaN  ...  99.79123       NaN   NaN          NaN
# 14    NaN   NaN   NaN   NaN  ...  68.37533       NaN   NaN          NaN
# ..    ...   ...   ...   ...  ...       ...       ...   ...          ...
# 255   NaN   NaN   NaN   NaN  ...       NaN  95.00038   NaN          NaN
# 256   NaN   NaN   NaN   NaN  ...       NaN  87.50631   NaN          NaN
# 257   NaN   NaN   NaN   NaN  ...  86.12593  86.30101   NaN          NaN
# 261   NaN   NaN   NaN   NaN  ...  87.04667       NaN   NaN          NaN
# 262   NaN   NaN   NaN   NaN  ...       NaN  86.74796   NaN          NaN
#
# [120 rows x 61 columns]
# (120, 61)

# %%
from sklearn.preprocessing import Imputer
from sklearn.linear_model import LinearRegression

def predictValueImputed(rowNo):
    startRow = rowNo
    endRow = rowNo + 1
    x1 = np.arange(1972, 2018 + 2)
    X = x1[:-1]
    X = X.reshape(-1,1)
    # display(X)
    display(X.shape)
    y1 = df3.iloc[startRow:endRow,12:-2].to_numpy()
    y = y1.reshape(-1,1)
    display(y.shape)

    imputer = Imputer()
    y_imputed = imputer.fit_transform(y)

    reg = LinearRegression().fit(X, y_imputed)
    display(rowNo)
    display(df.iloc[startRow:endRow,0])
    display(reg.predict([[2019]])[0][0])
    display(reg.predict([[2020]])[0][0])
    display(reg.predict([[2021]])[0][0])
    display(reg.predict([[2022]])[0][0])
    display(reg.predict([[2023]])[0][0])
    display(reg.predict([[2024]])[0][0])
    display(reg.predict([[2025]])[0][0])
    # predictions = []
    predictions2019 = (reg.predict([[2019]])[0][0])
    predictions2020 =  (reg.predict([[2020]])[0][0])
    predictions2021 =  (reg.predict([[2021]])[0][0])
    predictions2022 =  (reg.predict([[2022]])[0][0])
    predictions2023 =  (reg.predict([[2023]])[0][0])
    predictions2024 =  (reg.predict([[2024]])[0][0])
    predictions2025 =  (reg.predict([[2025]])[0][0])

    return predictions2019,predictions2020,predictions2021,predictions2022,predictions2023,predictions2024,predictions2025

# %%
p2019 = []
p2020 = []
p2021 = []
p2022 = []
p2023 = []
p2024 = []
p2025 = []
display(df3.shape[0])
for y in range(df3.shape[0]):
    display(y)
    predictions2019,predictions2020,predictions2021,predictions2022,predictions2023,predictions2024,predictions2025 = predictValueImputed(y)
    p2019.append(predictions2019)
    p2020.append(predictions2020)
    p2021.append(predictions2021)
    p2022.append(predictions2022)
    p2023.append(predictions2023)
    p2024.append(predictions2024)
    p2025.append(predictions2025)
# Out:
# 120
# 0
# (47, 1)
# (47, 1)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:66: DeprecationWarning: Class Imputer is deprecated; Imputer was deprecated in version 0.20 and will be removed in 0.22. Import impute.SimpleImputer from sklearn instead.
#   warnings.warn(msg, category=DeprecationWarning)
# 0
# 0    Aruba
# Name: Country Name, dtype: object
# 97.36639099722481
# 97.36594862210917
# 97.36550624699355
# 97.36506387187791
# 97.36462149676228
# 97.36417912164664
# 97.363736746531
# 1
# (47, 1)
# (47, 1)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:66: DeprecationWarning: Class Imputer is deprecated; Imputer was deprecated in version 0.20 and will be removed in 0.22. Import impute.SimpleImputer from sklearn instead.
#   warnings.warn(msg, category=DeprecationWarning)
# 1
# 1    Afghanistan
# Name: Country Name, dtype: object
# 74.86802492936056
# 75.39038589201812
# 75.91274685467567
# 76.43510781733346
# 76.95746877999102
# 77.4798297426488
# 78.00219070530636
# 2
# (47, 1)
# (47, 1)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:66: DeprecationWarning: Class Imputer is deprecated; Imputer was deprecated in version 0.20 and will be removed in 0.22. Import impute.SimpleImputer from sklearn instead.
#   warnings.warn(msg, category=DeprecationWarning)
# 2
# 2    Angola
# Name: Country Name, dtype: object
# 98.8246463602314
# 98.84803933751036
# 98.87143231478932
# 98.89482529206828
# 98.91821826934724
# 98.9416112466262
# 98.96500422390515
# 3
# (47, 1)
# (47, 1)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:66: DeprecationWarning: Class Imputer is deprecated; Imputer was deprecated in version 0.20 and will be removed in 0.22. Import impute.SimpleImputer from sklearn instead.
#   warnings.warn(msg, category=DeprecationWarning)
# 3
# 3    Albania
# Name: Country Name, dtype: object
# 99.7112987802826
# 99.7128044436556
# 99.71431010702861
# 99.7158157704016
# 99.7173214337746
# 99.7188270971476
# 99.7203327605206
# 4
# (47, 1)
# (47, 1)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:66: DeprecationWarning: Class Imputer is deprecated; Imputer was deprecated in version 0.20 and will be removed in 0.22. Import impute.SimpleImputer from sklearn instead.
#   warnings.warn(msg, category=DeprecationWarning)
# 4
# 4    Andorra
# Name: Country Name, dtype: object
# 52.77411948110904
# 52.90897160884589
# 53.04382373658268
# 53.17867586431947
# 53.313527992056265
# 53.448380119793114
# 53.58323224752991
# 5
# (47, 1)
# (47, 1)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:66: DeprecationWarning: Class Imputer is deprecated; Imputer was deprecated in version 0.20 and will be removed in 0.22. Import impute.SimpleImputer from sklearn instead.
#   warnings.warn(msg, category=DeprecationWarning)
# 5
# 5    Arab World
# Name: Country Name, dtype: object
# 31.95880991276509
# 32.02376573763591
# 32.088721562506734
# 32.153677387377584
# 32.218633212248406
# 32.283589037119256
# 32.34854486199008
# 6
# (47, 1)
# (47, 1)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:66: DeprecationWarning: Class Imputer is deprecated; Imputer was deprecated in version 0.20 and will be removed in 0.22. Import impute.SimpleImputer from sklearn instead.
#   warnings.warn(msg, category=DeprecationWarning)
# 6
# 6    United Arab Emirates
# Name: Country Name, dtype: object
# 25.856618976904883
# 25.97330758933802
# 26.08999620177113
# 26.206684814204237
# 26.323373426637346
# 26.440062039070455
# 26.556750651503563
# 7
# (47, 1)
# (47, 1)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:66: DeprecationWarning: Class Imputer is deprecated; Imputer was deprecated in version 0.20 and will be removed in 0.22. Import impute.SimpleImputer from sklearn instead.
#   warnings.warn(msg, category=DeprecationWarning)
# 7
# 7    Argentina
# Name: Country Name, dtype: object
# 61.68446603921524
# 61.88612566002547
# 62.08778528083565
# 62.28944490164582
# 62.491104522456055
# 62.69276414326623
# 62.894423764076464
# 8
# (47, 1)
# (47, 1)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:66: DeprecationWarning: Class Imputer is deprecated; Imputer was deprecated in version 0.20 and will be removed in 0.22. Import impute.SimpleImputer from sklearn instead.
#   warnings.warn(msg, category=DeprecationWarning)
# 8
# 8    Armenia
# Name: Country Name, dtype: object
# 91.39447846509402
# 91.49288982010528
# 91.5913011751165
# 91.68971253012775
# 91.788123885139
# 91.88653524015022
# 91.98494659516147
# 9
# (47, 1)
# (47, 1)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:66: DeprecationWarning: Class Imputer is deprecated; Imputer was deprecated in version 0.20 and will be removed in 0.22. Import impute.SimpleImputer from sklearn instead.
#   warnings.warn(msg, category=DeprecationWarning)
# 9
# 9    American Samoa
# Name: Country Name, dtype: object
# 89.49891303227975
# 89.60916960844142
# 89.71942618460307
# 89.82968276076471
# 89.93993933692639
# 90.05019591308803
# 90.1604524892497
# 10
# (47, 1)
# (47, 1)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:66: DeprecationWarning: Class Imputer is deprecated; Imputer was deprecated in version 0.20 and will be removed in 0.22. Import impute.SimpleImputer from sklearn instead.
#   warnings.warn(msg, category=DeprecationWarning)
# 10
# 10    Antigua and Barbuda
# Name: Country Name, dtype: object
# 91.46393602647127
# 91.53266283758198
# 91.60138964869269
# 91.6701164598034
# 91.7388432709141
# 91.80757008202478
# 91.87629689313549
# 11
# (47, 1)
# (47, 1)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:66: DeprecationWarning: Class Imputer is deprecated; Imputer was deprecated in version 0.20 and will be removed in 0.22. Import impute.SimpleImputer from sklearn instead.
#   warnings.warn(msg, category=DeprecationWarning)
# 11
# 11    Australia
# Name: Country Name, dtype: object
# 99.5999993217532
# 99.59999932528207
# 99.59999932881092
# 99.59999933233978
# 99.59999933586865
# 99.5999993393975
# 99.59999934292637
# 12
# (47, 1)
# (47, 1)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:66: DeprecationWarning: Class Imputer is deprecated; Imputer was deprecated in version 0.20 and will be removed in 0.22. Import impute.SimpleImputer from sklearn instead.
#   warnings.warn(msg, category=DeprecationWarning)
# 12
# 12    Austria
# Name: Country Name, dtype: object
# 91.55551749349108
# 91.60774344862351
# 91.65996940375595
# 91.7121953588884
# 91.76442131402084
# 91.81664726915328
# 91.86887322428572
# 13
# (47, 1)
# (47, 1)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:66: DeprecationWarning: Class Imputer is deprecated; Imputer was deprecated in version 0.20 and will be removed in 0.22. Import impute.SimpleImputer from sklearn instead.
#   warnings.warn(msg, category=DeprecationWarning)
# 13
# 13    Azerbaijan
# Name: Country Name, dtype: object
# 36.71630824949197
# 36.77403617671182
# 36.83176410393165
# 36.88949203115149
# 36.947219958371335
# 37.004947885591164
# 37.06267581281101
# 14
# (47, 1)
# (47, 1)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:66: DeprecationWarning: Class Imputer is deprecated; Imputer was deprecated in version 0.20 and will be removed in 0.22. Import impute.SimpleImputer from sklearn instead.
#   warnings.warn(msg, category=DeprecationWarning)
# 14
# 14    Burundi
# Name: Country Name, dtype: object
# 98.79856514923398
# 98.81163326581526
# 98.82470138239653
# 98.83776949897779
# 98.85083761555906
# 98.86390573214032
# 98.8769738487216
# 15
# (47, 1)
# (47, 1)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:66: DeprecationWarning: Class Imputer is deprecated; Imputer was deprecated in version 0.20 and will be removed in 0.22. Import impute.SimpleImputer from sklearn instead.
#   warnings.warn(msg, category=DeprecationWarning)
# 15
# 15    Belgium
# Name: Country Name, dtype: object
# 96.54497257881559
# 96.56496990661219
# 96.5849672344088
# 96.60496456220541
# 96.62496189000201
# 96.64495921779863
# 96.66495654559523
# 16
# (47, 1)
# (47, 1)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:66: DeprecationWarning: Class Imputer is deprecated; Imputer was deprecated in version 0.20 and will be removed in 0.22. Import impute.SimpleImputer from sklearn instead.
#   warnings.warn(msg, category=DeprecationWarning)
# 16
# 16    Benin
# Name: Country Name, dtype: object
# 87.28169092173493
# 87.36696366119037
# 87.4522364006458
# 87.5375091401012
# 87.62278187955664
# 87.70805461901207
# 87.79332735846751
# 17
# (47, 1)
# (47, 1)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:66: DeprecationWarning: Class Imputer is deprecated; Imputer was deprecated in version 0.20 and will be removed in 0.22. Import impute.SimpleImputer from sklearn instead.
#   warnings.warn(msg, category=DeprecationWarning)
# 17
# 17    Burkina Faso
# Name: Country Name, dtype: object
# 42.48226036127691
# 42.50731511791405
# 42.53236987455118
# 42.55742463118832
# 42.58247938782545
# 42.60753414446259
# 42.63258890109972
# 18
# (47, 1)
# (47, 1)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:66: DeprecationWarning: Class Imputer is deprecated; Imputer was deprecated in version 0.20 and will be removed in 0.22. Import impute.SimpleImputer from sklearn instead.
#   warnings.warn(msg, category=DeprecationWarning)
# 18
# 18    Bangladesh
# Name: Country Name, dtype: object
# 68.18301281687238
# 68.28508118914525
# 68.38714956141808
# 68.48921793369092
# 68.59128630596376
# 68.6933546782366
# 68.79542305050944
# 19
# (47, 1)
# (47, 1)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:66: DeprecationWarning: Class Imputer is deprecated; Imputer was deprecated in version 0.20 and will be removed in 0.22. Import impute.SimpleImputer from sklearn instead.
#   warnings.warn(msg, category=DeprecationWarning)
# 19
# 19    Bulgaria
# Name: Country Name, dtype: object
# 93.48261782040208
# 93.49490681168942
# 93.50719580297674
# 93.51948479426407
# 93.5317737855514
# 93.54406277683873
# 93.55635176812606
# 20
# (47, 1)
# (47, 1)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:66: DeprecationWarning: Class Imputer is deprecated; Imputer was deprecated in version 0.20 and will be removed in 0.22. Import impute.SimpleImputer from sklearn instead.
#   warnings.warn(msg, category=DeprecationWarning)
# 20
# 20    Bahrain
# Name: Country Name, dtype: object
# 89.53771292606491
# 89.5668946533062
# 89.59607638054749
# 89.62525810778877
# 89.65443983503005
# 89.68362156227133
# 89.7128032895126
# 21
# (47, 1)
# (47, 1)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:66: DeprecationWarning: Class Imputer is deprecated; Imputer was deprecated in version 0.20 and will be removed in 0.22. Import impute.SimpleImputer from sklearn instead.
#   warnings.warn(msg, category=DeprecationWarning)
# 21
# 21    Bahamas, The
# Name: Country Name, dtype: object
# 90.14124583789696
# 90.20339204961802
# 90.26553826133906
# 90.3276844730601
# 90.38983068478116
# 90.4519768965022
# 90.51412310822326
# 22
# (47, 1)
# (47, 1)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:66: DeprecationWarning: Class Imputer is deprecated; Imputer was deprecated in version 0.20 and will be removed in 0.22. Import impute.SimpleImputer from sklearn instead.
#   warnings.warn(msg, category=DeprecationWarning)
# 22
# 22    Bosnia and Herzegovina
# Name: Country Name, dtype: object
# 71.21674398207297
# 71.27830041092196
# 71.33985683977095
# 71.40141326861992
# 71.4629696974689
# 71.5245261263179
# 71.58608255516688
# 23
# (47, 1)
# (47, 1)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:66: DeprecationWarning: Class Imputer is deprecated; Imputer was deprecated in version 0.20 and will be removed in 0.22. Import impute.SimpleImputer from sklearn instead.
#   warnings.warn(msg, category=DeprecationWarning)
# 23
# 23    Belarus
# Name: Country Name, dtype: object
# 99.215542915882
# 99.85132041457223
# 100.48709791326246
# 101.12287541195269
# 101.75865291064292
# 102.39443040933315
# 103.03020790802339
# 24
# (47, 1)
# (47, 1)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:66: DeprecationWarning: Class Imputer is deprecated; Imputer was deprecated in version 0.20 and will be removed in 0.22. Import impute.SimpleImputer from sklearn instead.
#   warnings.warn(msg, category=DeprecationWarning)
# 24
# 24    Belize
# Name: Country Name, dtype: object
# 79.231589700001
# 79.85819803102072
# 80.48480636204044
# 81.11141469306017
# 81.7380230240799
# 82.36463135509985
# 82.99123968611957
# 25
# (47, 1)
# (47, 1)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:66: DeprecationWarning: Class Imputer is deprecated; Imputer was deprecated in version 0.20 and will be removed in 0.22. Import impute.SimpleImputer from sklearn instead.
#   warnings.warn(msg, category=DeprecationWarning)
# 25
# 25    Bermuda
# Name: Country Name, dtype: object
# 98.52829896961134
# 99.1191866484894
# 99.71007432736724
# 100.30096200624507
# 100.8918496851229
# 101.48273736400097
# 102.0736250428788
# 26
# (47, 1)
# (47, 1)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:66: DeprecationWarning: Class Imputer is deprecated; Imputer was deprecated in version 0.20 and will be removed in 0.22. Import impute.SimpleImputer from sklearn instead.
#   warnings.warn(msg, category=DeprecationWarning)
# 26
# 26    Bolivia
# Name: Country Name, dtype: object
# 98.37746488226395
# 98.4405437567415
# 98.50362263121906
# 98.56670150569663
# 98.62978038017418
# 98.69285925465174
# 98.7559381291293
# 27
# (47, 1)
# (47, 1)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:66: DeprecationWarning: Class Imputer is deprecated; Imputer was deprecated in version 0.20 and will be removed in 0.22. Import impute.SimpleImputer from sklearn instead.
#   warnings.warn(msg, category=DeprecationWarning)
# 27
# 27    Brazil
# Name: Country Name, dtype: object
# 97.56041818046882
# 97.57727034153652
# 97.59412250260424
# 97.61097466367195
# 97.62782682473966
# 97.64467898580737
# 97.66153114687509
# 28
# (47, 1)
# (47, 1)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:66: DeprecationWarning: Class Imputer is deprecated; Imputer was deprecated in version 0.20 and will be removed in 0.22. Import impute.SimpleImputer from sklearn instead.
#   warnings.warn(msg, category=DeprecationWarning)
# 28
# 28    Barbados
# Name: Country Name, dtype: object
# 92.71215765820678
# 92.75304905450383
# 92.7939404508009
# 92.83483184709796
# 92.87572324339503
# 92.91661463969209
# 92.95750603598916
# 29
# (47, 1)
# (47, 1)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:66: DeprecationWarning: Class Imputer is deprecated; Imputer was deprecated in version 0.20 and will be removed in 0.22. Import impute.SimpleImputer from sklearn instead.
#   warnings.warn(msg, category=DeprecationWarning)
# 29
# 29    Brunei Darussalam
# Name: Country Name, dtype: object
# 67.18040202667788
# 67.34935887772883
# 67.51831572877984
# 67.68727257983085
# 67.85622943088185
# 68.02518628193286
# 68.19414313298381
# 30
# (47, 1)
# (47, 1)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:66: DeprecationWarning: Class Imputer is deprecated; Imputer was deprecated in version 0.20 and will be removed in 0.22. Import impute.SimpleImputer from sklearn instead.
#   warnings.warn(msg, category=DeprecationWarning)
# 30
# 30    Bhutan
# Name: Country Name, dtype: object
# 97.94026764834925
# 97.96027996451446
# 97.98029228067968
# 98.0003045968449
# 98.0203169130101
# 98.04032922917531
# 98.06034154534053
# 31
# (47, 1)
# (47, 1)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:66: DeprecationWarning: Class Imputer is deprecated; Imputer was deprecated in version 0.20 and will be removed in 0.22. Import impute.SimpleImputer from sklearn instead.
#   warnings.warn(msg, category=DeprecationWarning)
# 31
# 31    Botswana
# Name: Country Name, dtype: object
# 37.512412960831796
# 37.546272999462644
# 37.58013303809349
# 37.61399307672434
# 37.64785311535519
# 37.68171315398605
# 37.7155731926169
# 32
# (47, 1)
# (47, 1)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:66: DeprecationWarning: Class Imputer is deprecated; Imputer was deprecated in version 0.20 and will be removed in 0.22. Import impute.SimpleImputer from sklearn instead.
#   warnings.warn(msg, category=DeprecationWarning)
# 32
# 32    Central African Republic
# Name: Country Name, dtype: object
# 62.75276490535538
# 62.83278839283855
# 62.912811880321755
# 62.99283536780493
# 63.07285885528813
# 63.152882342771335
# 63.23290583025451
# 33
# (47, 1)
# (47, 1)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:66: DeprecationWarning: Class Imputer is deprecated; Imputer was deprecated in version 0.20 and will be removed in 0.22. Import impute.SimpleImputer from sklearn instead.
#   warnings.warn(msg, category=DeprecationWarning)
# 33
# 33    Canada
# Name: Country Name, dtype: object
# 94.22082450574544
# 94.23379432314675
# 94.24676414054807
# 94.25973395794938
# 94.2727037753507
# 94.28567359275202
# 94.29864341015333
# 34
# (47, 1)
# (47, 1)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:66: DeprecationWarning: Class Imputer is deprecated; Imputer was deprecated in version 0.20 and will be removed in 0.22. Import impute.SimpleImputer from sklearn instead.
#   warnings.warn(msg, category=DeprecationWarning)
# 34
# 34    Central Europe and the Baltics
# Name: Country Name, dtype: object
# 98.5999993217532
# 98.59999932528207
# 98.59999932881092
# 98.59999933233978
# 98.59999933586865
# 98.5999993393975
# 98.59999934292637
# 35
# (47, 1)
# (47, 1)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:66: DeprecationWarning: Class Imputer is deprecated; Imputer was deprecated in version 0.20 and will be removed in 0.22. Import impute.SimpleImputer from sklearn instead.
#   warnings.warn(msg, category=DeprecationWarning)
# 35
# 35    Switzerland
# Name: Country Name, dtype: object
# 74.65298631308177
# 74.68100408109103
# 74.70902184910031
# 74.73703961710956
# 74.76505738511884
# 74.7930751531281
# 74.82109292113736
# 36
# (47, 1)
# (47, 1)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:66: DeprecationWarning: Class Imputer is deprecated; Imputer was deprecated in version 0.20 and will be removed in 0.22. Import impute.SimpleImputer from sklearn instead.
#   warnings.warn(msg, category=DeprecationWarning)
# 36
# 36    Channel Islands
# Name: Country Name, dtype: object
# 85.85579802035151
# 85.86814072953283
# 85.88048343871415
# 85.89282614789545
# 85.90516885707677
# 85.91751156625809
# 85.9298542754394
# 37
# (47, 1)
# (47, 1)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:66: DeprecationWarning: Class Imputer is deprecated; Imputer was deprecated in version 0.20 and will be removed in 0.22. Import impute.SimpleImputer from sklearn instead.
#   warnings.warn(msg, category=DeprecationWarning)
# 37
# 37    Chile
# Name: Country Name, dtype: object
# 57.156925714583565
# 57.35509384495157
# 57.553261975319515
# 57.75143010568746
# 57.94959823605541
# 58.147766366423355
# 58.34593449679136
# 38
# (47, 1)
# (47, 1)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:66: DeprecationWarning: Class Imputer is deprecated; Imputer was deprecated in version 0.20 and will be removed in 0.22. Import impute.SimpleImputer from sklearn instead.
#   warnings.warn(msg, category=DeprecationWarning)
# 38
# 38    China
# Name: Country Name, dtype: object
# 91.11825282610266
# 91.68915904705341
# 92.26006526800438
# 92.83097148895513
# 93.4018777099061
# 93.97278393085685
# 94.5436901518076
# 39
# (47, 1)
# (47, 1)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:66: DeprecationWarning: Class Imputer is deprecated; Imputer was deprecated in version 0.20 and will be removed in 0.22. Import impute.SimpleImputer from sklearn instead.
#   warnings.warn(msg, category=DeprecationWarning)
# 39
# 39    Cote d'Ivoire
# Name: Country Name, dtype: object
# 85.7941374051045
# 86.32282406946229
# 86.85151073381985
# 87.38019739817742
# 87.90888406253521
# 88.43757072689277
# 88.96625739125034
# 40
# (47, 1)
# (47, 1)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:66: DeprecationWarning: Class Imputer is deprecated; Imputer was deprecated in version 0.20 and will be removed in 0.22. Import impute.SimpleImputer from sklearn instead.
#   warnings.warn(msg, category=DeprecationWarning)
# 40
# 40    Cameroon
# Name: Country Name, dtype: object
# 62.43780290497136
# 62.7448358097638
# 63.05186871455612
# 63.35890161934856
# 63.665934524140994
# 63.972967428933316
# 64.28000033372575
# 41
# (47, 1)
# (47, 1)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:66: DeprecationWarning: Class Imputer is deprecated; Imputer was deprecated in version 0.20 and will be removed in 0.22. Import impute.SimpleImputer from sklearn instead.
#   warnings.warn(msg, category=DeprecationWarning)
# 41
# 41    Congo, Dem. Rep.
# Name: Country Name, dtype: object
# 65.18486218910505
# 65.47018399065848
# 65.75550579221192
# 66.04082759376536
# 66.3261493953188
# 66.61147119687212
# 66.89679299842555
# 42
# (47, 1)
# (47, 1)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:66: DeprecationWarning: Class Imputer is deprecated; Imputer was deprecated in version 0.20 and will be removed in 0.22. Import impute.SimpleImputer from sklearn instead.
#   warnings.warn(msg, category=DeprecationWarning)
# 42
# 42    Congo, Rep.
# Name: Country Name, dtype: object
# 92.67959854330235
# 92.79066071923066
# 92.901722895159
# 93.01278507108731
# 93.12384724701562
# 93.23490942294393
# 93.34597159887227
# 43
# (47, 1)
# (47, 1)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:66: DeprecationWarning: Class Imputer is deprecated; Imputer was deprecated in version 0.20 and will be removed in 0.22. Import impute.SimpleImputer from sklearn instead.
#   warnings.warn(msg, category=DeprecationWarning)
# 43
# 43    Colombia
# Name: Country Name, dtype: object
# 60.89609438864625
# 61.20311527659862
# 61.51013616455111
# 61.81715705250349
# 62.124177940455866
# 62.431198828408355
# 62.73821971636073
# 44
# (47, 1)
# (47, 1)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:66: DeprecationWarning: Class Imputer is deprecated; Imputer was deprecated in version 0.20 and will be removed in 0.22. Import impute.SimpleImputer from sklearn instead.
#   warnings.warn(msg, category=DeprecationWarning)
# 44
# 44    Comoros
# Name: Country Name, dtype: object
# 61.77738840841374
# 61.87623625492421
# 61.975084101434646
# 62.073931947945084
# 62.17277979445552
# 62.27162764096596
# 62.370475487476426
# 45
# (47, 1)
# (47, 1)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:66: DeprecationWarning: Class Imputer is deprecated; Imputer was deprecated in version 0.20 and will be removed in 0.22. Import impute.SimpleImputer from sklearn instead.
#   warnings.warn(msg, category=DeprecationWarning)
# 45
# 45    Cabo Verde
# Name: Country Name, dtype: object
# 79.87155630634055
# 80.10694438309673
# 80.34233245985291
# 80.57772053660904
# 80.81310861336522
# 81.0484966901214
# 81.28388476687752
# 46
# (47, 1)
# (47, 1)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:66: DeprecationWarning: Class Imputer is deprecated; Imputer was deprecated in version 0.20 and will be removed in 0.22. Import impute.SimpleImputer from sklearn instead.
#   warnings.warn(msg, category=DeprecationWarning)
# 46
# 46    Costa Rica
# Name: Country Name, dtype: object
# 92.83693480345381
# 92.93122179351725
# 93.02550878358069
# 93.11979577364413
# 93.21408276370757
# 93.30836975377103
# 93.40265674383447
# 47
# (47, 1)
# (47, 1)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:66: DeprecationWarning: Class Imputer is deprecated; Imputer was deprecated in version 0.20 and will be removed in 0.22. Import impute.SimpleImputer from sklearn instead.
#   warnings.warn(msg, category=DeprecationWarning)
# 47
# 47    Caribbean small states
# Name: Country Name, dtype: object
# 75.5521830668282
# 75.56815507237624
# 75.5841270779243
# 75.60009908347234
# 75.61607108902038
# 75.63204309456843
# 75.64801510011648
# 48
# (47, 1)
# (47, 1)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:66: DeprecationWarning: Class Imputer is deprecated; Imputer was deprecated in version 0.20 and will be removed in 0.22. Import impute.SimpleImputer from sklearn instead.
#   warnings.warn(msg, category=DeprecationWarning)
# 48
# 48    Cuba
# Name: Country Name, dtype: object
# 93.72785882669285
# 93.98011080720585
# 94.23236278771884
# 94.48461476823184
# 94.73686674874483
# 94.98911872925777
# 95.24137070977076
# 49
# (47, 1)
# (47, 1)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:66: DeprecationWarning: Class Imputer is deprecated; Imputer was deprecated in version 0.20 and will be removed in 0.22. Import impute.SimpleImputer from sklearn instead.
#   warnings.warn(msg, category=DeprecationWarning)
# 49
# 49    Curacao
# Name: Country Name, dtype: object
# 94.02463579086941
# 94.38208184175767
# 94.73952789264581
# 95.09697394353407
# 95.45441999442221
# 95.81186604531035
# 96.16931209619861
# 50
# (47, 1)
# (47, 1)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:66: DeprecationWarning: Class Imputer is deprecated; Imputer was deprecated in version 0.20 and will be removed in 0.22. Import impute.SimpleImputer from sklearn instead.
#   warnings.warn(msg, category=DeprecationWarning)
# 50
# 50    Cayman Islands
# Name: Country Name, dtype: object
# 69.53089374802722
# 69.5514859782968
# 69.57207820856635
# 69.59267043883592
# 69.6132626691055
# 69.63385489937505
# 69.65444712964464
# 51
# (47, 1)
# (47, 1)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:66: DeprecationWarning: Class Imputer is deprecated; Imputer was deprecated in version 0.20 and will be removed in 0.22. Import impute.SimpleImputer from sklearn instead.
#   warnings.warn(msg, category=DeprecationWarning)
# 51
# 51    Cyprus
# Name: Country Name, dtype: object
# 94.558408044658
# 94.88218016895758
# 95.20595229325716
# 95.52972441755662
# 95.8534965418562
# 96.17726866615567
# 96.50104079045525
# 52
# (47, 1)
# (47, 1)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:66: DeprecationWarning: Class Imputer is deprecated; Imputer was deprecated in version 0.20 and will be removed in 0.22. Import impute.SimpleImputer from sklearn instead.
#   warnings.warn(msg, category=DeprecationWarning)
# 52
# 52    Czech Republic
# Name: Country Name, dtype: object
# 59.56861135354859
# 59.900991315900114
# 60.23337127825164
# 60.56575124060305
# 60.89813120295457
# 61.2305111653061
# 61.56289112765762
# 53
# (47, 1)
# (47, 1)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:66: DeprecationWarning: Class Imputer is deprecated; Imputer was deprecated in version 0.20 and will be removed in 0.22. Import impute.SimpleImputer from sklearn instead.
#   warnings.warn(msg, category=DeprecationWarning)
# 53
# 53    Germany
# Name: Country Name, dtype: object
# 58.59776918483493
# 58.800593733870926
# 59.00341828290692
# 59.20624283194297
# 59.40906738097897
# 59.61189193001502
# 59.814716479051015
# 54
# (47, 1)
# (47, 1)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:66: DeprecationWarning: Class Imputer is deprecated; Imputer was deprecated in version 0.20 and will be removed in 0.22. Import impute.SimpleImputer from sklearn instead.
#   warnings.warn(msg, category=DeprecationWarning)
# 54
# 54    Djibouti
# Name: Country Name, dtype: object
# 90.97256932271063
# 90.98754861839508
# 91.00252791407955
# 91.017507209764
# 91.03248650544847
# 91.04746580113294
# 91.0624450968174
# 55
# (47, 1)
# (47, 1)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:66: DeprecationWarning: Class Imputer is deprecated; Imputer was deprecated in version 0.20 and will be removed in 0.22. Import impute.SimpleImputer from sklearn instead.
#   warnings.warn(msg, category=DeprecationWarning)
# 55
# 55    Dominica
# Name: Country Name, dtype: object
# 76.63953956154978
# 77.20566398212964
# 77.77178840270972
# 78.3379128232898
# 78.90403724386988
# 79.47016166444973
# 80.03628608502981
# 56
# (47, 1)
# (47, 1)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:66: DeprecationWarning: Class Imputer is deprecated; Imputer was deprecated in version 0.20 and will be removed in 0.22. Import impute.SimpleImputer from sklearn instead.
#   warnings.warn(msg, category=DeprecationWarning)
# 56
# 56    Denmark
# Name: Country Name, dtype: object
# 85.64131860662542
# 86.178265965224
# 86.71521332382258
# 87.25216068242116
# 87.78910804101952
# 88.3260553996181
# 88.86300275821668
# 57
# (47, 1)
# (47, 1)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:66: DeprecationWarning: Class Imputer is deprecated; Imputer was deprecated in version 0.20 and will be removed in 0.22. Import impute.SimpleImputer from sklearn instead.
#   warnings.warn(msg, category=DeprecationWarning)
# 57
# 57    Dominican Republic
# Name: Country Name, dtype: object
# 98.7273957259439
# 99.2668572203446
# 99.80631871474532
# 100.3457802091458
# 100.88524170354651
# 101.424703197947
# 101.96416469234771
# 58
# (47, 1)
# (47, 1)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:66: DeprecationWarning: Class Imputer is deprecated; Imputer was deprecated in version 0.20 and will be removed in 0.22. Import impute.SimpleImputer from sklearn instead.
#   warnings.warn(msg, category=DeprecationWarning)
# 58
# 58    Algeria
# Name: Country Name, dtype: object
# 93.83033634127605
# 93.84533509334989
# 93.86033384542372
# 93.87533259749756
# 93.89033134957141
# 93.90533010164525
# 93.92032885371908
# 59
# (47, 1)
# (47, 1)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:66: DeprecationWarning: Class Imputer is deprecated; Imputer was deprecated in version 0.20 and will be removed in 0.22. Import impute.SimpleImputer from sklearn instead.
#   warnings.warn(msg, category=DeprecationWarning)
# 59
# 59    East Asia & Pacific (excluding high income)
# Name: Country Name, dtype: object
# 58.87726394277166
# 59.009393077209495
# 59.141522211647384
# 59.27365134608527
# 59.405780480523106
# 59.537909614960995
# 59.670038749398884
# 60
# (47, 1)
# (47, 1)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:66: DeprecationWarning: Class Imputer is deprecated; Imputer was deprecated in version 0.20 and will be removed in 0.22. Import impute.SimpleImputer from sklearn instead.
#   warnings.warn(msg, category=DeprecationWarning)
# 60
# 60    Early-demographic dividend
# Name: Country Name, dtype: object
# 95.69159070372125
# 95.74053952180029
# 95.78948833987933
# 95.83843715795837
# 95.88738597603741
# 95.93633479411645
# 95.9852836121955
# 61
# (47, 1)
# (47, 1)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:66: DeprecationWarning: Class Imputer is deprecated; Imputer was deprecated in version 0.20 and will be removed in 0.22. Import impute.SimpleImputer from sklearn instead.
#   warnings.warn(msg, category=DeprecationWarning)
# 61
# 61    East Asia & Pacific
# Name: Country Name, dtype: object
# 82.9607458574817
# 83.77682914489424
# 84.59291243230655
# 85.40899571971909
# 86.22507900713163
# 87.04116229454416
# 87.8572455819567
# 62
# (47, 1)
# (47, 1)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:66: DeprecationWarning: Class Imputer is deprecated; Imputer was deprecated in version 0.20 and will be removed in 0.22. Import impute.SimpleImputer from sklearn instead.
#   warnings.warn(msg, category=DeprecationWarning)
# 62
# 62    Europe & Central Asia (excluding high income)
# Name: Country Name, dtype: object
# 93.71518551458838
# 93.773806216079
# 93.8324269175696
# 93.89104761906022
# 93.94966832055083
# 94.00828902204145
# 94.06690972353206
# 63
# (47, 1)
# (47, 1)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:66: DeprecationWarning: Class Imputer is deprecated; Imputer was deprecated in version 0.20 and will be removed in 0.22. Import impute.SimpleImputer from sklearn instead.
#   warnings.warn(msg, category=DeprecationWarning)
# 63
# 63    Europe & Central Asia
# Name: Country Name, dtype: object
# 87.89771264483124
# 88.45500793199972
# 89.01230321916842
# 89.56959850633689
# 90.12689379350559
# 90.68418908067406
# 91.24148436784276
# 64
# (47, 1)
# (47, 1)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:66: DeprecationWarning: Class Imputer is deprecated; Imputer was deprecated in version 0.20 and will be removed in 0.22. Import impute.SimpleImputer from sklearn instead.
#   warnings.warn(msg, category=DeprecationWarning)
# 64
# 64    Ecuador
# Name: Country Name, dtype: object
# 28.700948955291352
# 28.793391204507714
# 28.885833453724103
# 28.978275702940493
# 29.070717952156855
# 29.163160201373245
# 29.255602450589635
# 65
# (47, 1)
# (47, 1)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:66: DeprecationWarning: Class Imputer is deprecated; Imputer was deprecated in version 0.20 and will be removed in 0.22. Import impute.SimpleImputer from sklearn instead.
#   warnings.warn(msg, category=DeprecationWarning)
# 65
# 65    Egypt, Arab Rep.
# Name: Country Name, dtype: object
# 91.47188422374396
# 91.49177791466656
# 91.51167160558916
# 91.53156529651176
# 91.55145898743436
# 91.57135267835694
# 91.59124636927955
# 66
# (47, 1)
# (47, 1)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:66: DeprecationWarning: Class Imputer is deprecated; Imputer was deprecated in version 0.20 and will be removed in 0.22. Import impute.SimpleImputer from sklearn instead.
#   warnings.warn(msg, category=DeprecationWarning)
# 66
# 66    Euro area
# Name: Country Name, dtype: object
# 82.58174839763569
# 83.52273804447282
# 84.46372769130994
# 85.40471733814707
# 86.34570698498419
# 87.28669663182109
# 88.22768627865821
# 67
# (47, 1)
# (47, 1)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:66: DeprecationWarning: Class Imputer is deprecated; Imputer was deprecated in version 0.20 and will be removed in 0.22. Import impute.SimpleImputer from sklearn instead.
#   warnings.warn(msg, category=DeprecationWarning)
# 67
# 67    Eritrea
# Name: Country Name, dtype: object
# 96.26678406620391
# 96.29322600463135
# 96.31966794305879
# 96.34610988148623
# 96.37255181991367
# 96.3989937583411
# 96.42543569676855
# 68
# (47, 1)
# (47, 1)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:66: DeprecationWarning: Class Imputer is deprecated; Imputer was deprecated in version 0.20 and will be removed in 0.22. Import impute.SimpleImputer from sklearn instead.
#   warnings.warn(msg, category=DeprecationWarning)
# 68
# 68    Spain
# Name: Country Name, dtype: object
# 49.16436645131307
# 49.26050208548526
# 49.356637719657414
# 49.4527733538296
# 49.548908988001784
# 49.64504462217394
# 49.74118025634613
# 69
# (47, 1)
# (47, 1)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:66: DeprecationWarning: Class Imputer is deprecated; Imputer was deprecated in version 0.20 and will be removed in 0.22. Import impute.SimpleImputer from sklearn instead.
#   warnings.warn(msg, category=DeprecationWarning)
# 69
# 69    Estonia
# Name: Country Name, dtype: object
# 90.480172352286
# 90.51710907079261
# 90.55404578929924
# 90.59098250780585
# 90.62791922631247
# 90.6648559448191
# 90.7017926633257
# 70
# (47, 1)
# (47, 1)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:66: DeprecationWarning: Class Imputer is deprecated; Imputer was deprecated in version 0.20 and will be removed in 0.22. Import impute.SimpleImputer from sklearn instead.
#   warnings.warn(msg, category=DeprecationWarning)
# 70
# 70    Ethiopia
# Name: Country Name, dtype: object
# 60.95311043930496
# 60.982243970630165
# 61.01137750195537
# 61.04051103328058
# 61.06964456460579
# 61.098778095930996
# 61.1279116272562
# 71
# (47, 1)
# (47, 1)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:66: DeprecationWarning: Class Imputer is deprecated; Imputer was deprecated in version 0.20 and will be removed in 0.22. Import impute.SimpleImputer from sklearn instead.
#   warnings.warn(msg, category=DeprecationWarning)
# 71
# 71    European Union
# Name: Country Name, dtype: object
# 87.12397166700617
# 87.1877034528751
# 87.251435238744
# 87.31516702461292
# 87.37889881048181
# 87.44263059635074
# 87.50636238221963
# 72
# (47, 1)
# (47, 1)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:66: DeprecationWarning: Class Imputer is deprecated; Imputer was deprecated in version 0.20 and will be removed in 0.22. Import impute.SimpleImputer from sklearn instead.
#   warnings.warn(msg, category=DeprecationWarning)
# 72
# 72    Fragile and conflict affected situations
# Name: Country Name, dtype: object
# 49.122786099834286
# 49.255452944112506
# 49.38811978839067
# 49.52078663266883
# 49.65345347694699
# 49.786120321225155
# 49.91878716550332
# 73
# (47, 1)
# (47, 1)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:66: DeprecationWarning: Class Imputer is deprecated; Imputer was deprecated in version 0.20 and will be removed in 0.22. Import impute.SimpleImputer from sklearn instead.
#   warnings.warn(msg, category=DeprecationWarning)
# 73
# 73    Finland
# Name: Country Name, dtype: object
# 91.28069981036074
# 91.30244365662578
# 91.32418750289082
# 91.34593134915585
# 91.36767519542087
# 91.38941904168591
# 91.41116288795095
# 74
# (47, 1)
# (47, 1)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:66: DeprecationWarning: Class Imputer is deprecated; Imputer was deprecated in version 0.20 and will be removed in 0.22. Import impute.SimpleImputer from sklearn instead.
#   warnings.warn(msg, category=DeprecationWarning)
# 74
# 74    Fiji
# Name: Country Name, dtype: object
# 82.77498954950062
# 82.95662238926332
# 83.13825522902602
# 83.31988806878871
# 83.50152090855141
# 83.68315374831411
# 83.86478658807681
# 75
# (47, 1)
# (47, 1)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:66: DeprecationWarning: Class Imputer is deprecated; Imputer was deprecated in version 0.20 and will be removed in 0.22. Import impute.SimpleImputer from sklearn instead.
#   warnings.warn(msg, category=DeprecationWarning)
# 75
# 75    France
# Name: Country Name, dtype: object
# 54.42643786112188
# 54.53639325980848
# 54.6463486584951
# 54.756304057181694
# 54.86625945586832
# 54.97621485455494
# 55.086170253241534
# 76
# (47, 1)
# (47, 1)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:66: DeprecationWarning: Class Imputer is deprecated; Imputer was deprecated in version 0.20 and will be removed in 0.22. Import impute.SimpleImputer from sklearn instead.
#   warnings.warn(msg, category=DeprecationWarning)
# 76
# 76    Faroe Islands
# Name: Country Name, dtype: object
# 92.18544467653962
# 92.20769528267067
# 92.22994588880172
# 92.25219649493276
# 92.2744471010638
# 92.29669770719485
# 92.3189483133259
# 77
# (47, 1)
# (47, 1)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:66: DeprecationWarning: Class Imputer is deprecated; Imputer was deprecated in version 0.20 and will be removed in 0.22. Import impute.SimpleImputer from sklearn instead.
#   warnings.warn(msg, category=DeprecationWarning)
# 77
# 77    Micronesia, Fed. Sts.
# Name: Country Name, dtype: object
# 91.90846220452715
# 91.96235186524537
# 92.01624152596358
# 92.0701311866818
# 92.12402084740002
# 92.17791050811823
# 92.23180016883644
# 78
# (47, 1)
# (47, 1)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:66: DeprecationWarning: Class Imputer is deprecated; Imputer was deprecated in version 0.20 and will be removed in 0.22. Import impute.SimpleImputer from sklearn instead.
#   warnings.warn(msg, category=DeprecationWarning)
# 78
# 78    Gabon
# Name: Country Name, dtype: object
# 94.14264192772175
# 94.17984316226917
# 94.21704439681658
# 94.25424563136397
# 94.29144686591138
# 94.32864810045879
# 94.36584933500619
# 79
# (47, 1)
# (47, 1)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:66: DeprecationWarning: Class Imputer is deprecated; Imputer was deprecated in version 0.20 and will be removed in 0.22. Import impute.SimpleImputer from sklearn instead.
#   warnings.warn(msg, category=DeprecationWarning)
# 79
# 79    United Kingdom
# Name: Country Name, dtype: object
# 58.66422039260391
# 58.77753931477005
# 58.8908582369362
# 59.00417715910234
# 59.117496081268484
# 59.23081500343463
# 59.34413392560077
# 80
# (47, 1)
# (47, 1)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:66: DeprecationWarning: Class Imputer is deprecated; Imputer was deprecated in version 0.20 and will be removed in 0.22. Import impute.SimpleImputer from sklearn instead.
#   warnings.warn(msg, category=DeprecationWarning)
# 80
# 80    Georgia
# Name: Country Name, dtype: object
# 94.09025244542464
# 94.14705778827904
# 94.20386313113345
# 94.26066847398785
# 94.31747381684225
# 94.37427915969666
# 94.43108450255106
# 81
# (47, 1)
# (47, 1)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:66: DeprecationWarning: Class Imputer is deprecated; Imputer was deprecated in version 0.20 and will be removed in 0.22. Import impute.SimpleImputer from sklearn instead.
#   warnings.warn(msg, category=DeprecationWarning)
# 81
# 81    Ghana
# Name: Country Name, dtype: object
# 95.00825460605458
# 95.03101322327375
# 95.05377184049293
# 95.0765304577121
# 95.09928907493128
# 95.12204769215046
# 95.14480630936963
# 82
# (47, 1)
# (47, 1)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:66: DeprecationWarning: Class Imputer is deprecated; Imputer was deprecated in version 0.20 and will be removed in 0.22. Import impute.SimpleImputer from sklearn instead.
#   warnings.warn(msg, category=DeprecationWarning)
# 82
# 82    Gibraltar
# Name: Country Name, dtype: object
# 89.2942852242129
# 89.30306309215925
# 89.3118409601056
# 89.32061882805195
# 89.3293966959983
# 89.33817456394465
# 89.34695243189101
# 83
# (47, 1)
# (47, 1)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:66: DeprecationWarning: Class Imputer is deprecated; Imputer was deprecated in version 0.20 and will be removed in 0.22. Import impute.SimpleImputer from sklearn instead.
#   warnings.warn(msg, category=DeprecationWarning)
# 83
# 83    Guinea
# Name: Country Name, dtype: object
# 91.10419363951652
# 91.15759407642102
# 91.21099451332552
# 91.26439495023001
# 91.31779538713451
# 91.37119582403902
# 91.42459626094352
# 84
# (47, 1)
# (47, 1)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:66: DeprecationWarning: Class Imputer is deprecated; Imputer was deprecated in version 0.20 and will be removed in 0.22. Import impute.SimpleImputer from sklearn instead.
#   warnings.warn(msg, category=DeprecationWarning)
# 84
# 84    Gambia, The
# Name: Country Name, dtype: object
# 65.46799675209778
# 65.58161245002194
# 65.69522814794607
# 65.80884384587023
# 65.92245954379436
# 66.03607524171852
# 66.14969093964265
# 85
# (47, 1)
# (47, 1)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:66: DeprecationWarning: Class Imputer is deprecated; Imputer was deprecated in version 0.20 and will be removed in 0.22. Import impute.SimpleImputer from sklearn instead.
#   warnings.warn(msg, category=DeprecationWarning)
# 85
# 85    Guinea-Bissau
# Name: Country Name, dtype: object
# 70.72047391305318
# 71.46170636168449
# 72.2029388103158
# 72.94417125894711
# 73.68540370757842
# 74.42663615620972
# 75.16786860484103
# 86
# (47, 1)
# (47, 1)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:66: DeprecationWarning: Class Imputer is deprecated; Imputer was deprecated in version 0.20 and will be removed in 0.22. Import impute.SimpleImputer from sklearn instead.
#   warnings.warn(msg, category=DeprecationWarning)
# 86
# 86    Equatorial Guinea
# Name: Country Name, dtype: object
# 85.70739263083996
# 85.75532317675794
# 85.80325372267592
# 85.85118426859388
# 85.89911481451186
# 85.94704536042984
# 85.9949759063478
# 87
# (47, 1)
# (47, 1)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:66: DeprecationWarning: Class Imputer is deprecated; Imputer was deprecated in version 0.20 and will be removed in 0.22. Import impute.SimpleImputer from sklearn instead.
#   warnings.warn(msg, category=DeprecationWarning)
# 87
# 87    Greece
# Name: Country Name, dtype: object
# 44.791152456618654
# 44.84494892381105
# 44.89874539100345
# 44.95254185819585
# 45.00633832538825
# 45.06013479258065
# 45.11393125977305
# 88
# (47, 1)
# (47, 1)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:66: DeprecationWarning: Class Imputer is deprecated; Imputer was deprecated in version 0.20 and will be removed in 0.22. Import impute.SimpleImputer from sklearn instead.
#   warnings.warn(msg, category=DeprecationWarning)
# 88
# 88    Grenada
# Name: Country Name, dtype: object
# 96.1243552197132
# 96.18977424863483
# 96.25519327755647
# 96.32061230647811
# 96.38603133539972
# 96.45145036432136
# 96.516869393243
# 89
# (47, 1)
# (47, 1)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:66: DeprecationWarning: Class Imputer is deprecated; Imputer was deprecated in version 0.20 and will be removed in 0.22. Import impute.SimpleImputer from sklearn instead.
#   warnings.warn(msg, category=DeprecationWarning)
# 89
# 89    Greenland
# Name: Country Name, dtype: object
# 85.22650100237885
# 85.25815802157274
# 85.28981504076661
# 85.32147205996048
# 85.35312907915437
# 85.38478609834823
# 85.41644311754212
# 90
# (47, 1)
# (47, 1)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:66: DeprecationWarning: Class Imputer is deprecated; Imputer was deprecated in version 0.20 and will be removed in 0.22. Import impute.SimpleImputer from sklearn instead.
#   warnings.warn(msg, category=DeprecationWarning)
# 90
# 90    Guatemala
# Name: Country Name, dtype: object
# 61.60386951961982
# 61.77071057972876
# 61.93755163983775
# 62.104392699946686
# 62.27123376005562
# 62.438074820164616
# 62.60491588027355
# 91
# (47, 1)
# (47, 1)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:66: DeprecationWarning: Class Imputer is deprecated; Imputer was deprecated in version 0.20 and will be removed in 0.22. Import impute.SimpleImputer from sklearn instead.
#   warnings.warn(msg, category=DeprecationWarning)
# 91
# 91    Guam
# Name: Country Name, dtype: object
# 61.60850468114825
# 61.775327442387834
# 61.942150203627364
# 62.10897296486695
# 62.27579572610654
# 62.442618487346124
# 62.60944124858571
# 92
# (47, 1)
# (47, 1)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:66: DeprecationWarning: Class Imputer is deprecated; Imputer was deprecated in version 0.20 and will be removed in 0.22. Import impute.SimpleImputer from sklearn instead.
#   warnings.warn(msg, category=DeprecationWarning)
# 92
# 92    Guyana
# Name: Country Name, dtype: object
# 84.4742336620657
# 84.58186631082012
# 84.68949895957454
# 84.79713160832895
# 84.90476425708337
# 85.01239690583779
# 85.12002955459224
# 93
# (47, 1)
# (47, 1)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:66: DeprecationWarning: Class Imputer is deprecated; Imputer was deprecated in version 0.20 and will be removed in 0.22. Import impute.SimpleImputer from sklearn instead.
#   warnings.warn(msg, category=DeprecationWarning)
# 93
# 93    High income
# Name: Country Name, dtype: object
# 80.18021369052506
# 80.27125511448095
# 80.36229653843681
# 80.45333796239267
# 80.54437938634852
# 80.63542081030441
# 80.72646223426027
# 94
# (47, 1)
# (47, 1)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:66: DeprecationWarning: Class Imputer is deprecated; Imputer was deprecated in version 0.20 and will be removed in 0.22. Import impute.SimpleImputer from sklearn instead.
#   warnings.warn(msg, category=DeprecationWarning)
# 94
# 94    Hong Kong SAR, China
# Name: Country Name, dtype: object
# 93.30569465309901
# 93.30887626364479
# 93.31205787419059
# 93.31523948473638
# 93.31842109528216
# 93.32160270582796
# 93.32478431637375
# 95
# (47, 1)
# (47, 1)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:66: DeprecationWarning: Class Imputer is deprecated; Imputer was deprecated in version 0.20 and will be removed in 0.22. Import impute.SimpleImputer from sklearn instead.
#   warnings.warn(msg, category=DeprecationWarning)
# 95
# 95    Honduras
# Name: Country Name, dtype: object
# 77.65974665416431
# 77.76437952481513
# 77.86901239546594
# 77.97364526611673
# 78.07827813676755
# 78.18291100741837
# 78.28754387806916
# 96
# (47, 1)
# (47, 1)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:66: DeprecationWarning: Class Imputer is deprecated; Imputer was deprecated in version 0.20 and will be removed in 0.22. Import impute.SimpleImputer from sklearn instead.
#   warnings.warn(msg, category=DeprecationWarning)
# 96
# 96    Heavily indebted poor countries (HIPC)
# Name: Country Name, dtype: object
# 91.37485977179969
# 91.40132253623747
# 91.42778530067525
# 91.45424806511303
# 91.4807108295508
# 91.50717359398858
# 91.53363635842636
# 97
# (47, 1)
# (47, 1)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:66: DeprecationWarning: Class Imputer is deprecated; Imputer was deprecated in version 0.20 and will be removed in 0.22. Import impute.SimpleImputer from sklearn instead.
#   warnings.warn(msg, category=DeprecationWarning)
# 97
# 97    Croatia
# Name: Country Name, dtype: object
# 23.06558523953494
# 23.082944370688146
# 23.100303501841353
# 23.117662632994566
# 23.135021764147773
# 23.15238089530098
# 23.169740026454193
# 98
# (47, 1)
# (47, 1)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:66: DeprecationWarning: Class Imputer is deprecated; Imputer was deprecated in version 0.20 and will be removed in 0.22. Import impute.SimpleImputer from sklearn instead.
#   warnings.warn(msg, category=DeprecationWarning)
# 98
# 98    Haiti
# Name: Country Name, dtype: object
# 99.21059162183428
# 99.85484681880757
# 100.49910201578086
# 101.14335721275415
# 101.78761240972744
# 102.43186760670096
# 103.07612280367425
# 99
# (47, 1)
# (47, 1)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:66: DeprecationWarning: Class Imputer is deprecated; Imputer was deprecated in version 0.20 and will be removed in 0.22. Import impute.SimpleImputer from sklearn instead.
#   warnings.warn(msg, category=DeprecationWarning)
# 99
# 99    Hungary
# Name: Country Name, dtype: object
# 98.41565683263892
# 98.47255284487409
# 98.52944885710927
# 98.58634486934444
# 98.64324088157963
# 98.7001368938148
# 98.75703290604999
# 100
# (47, 1)
# (47, 1)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:66: DeprecationWarning: Class Imputer is deprecated; Imputer was deprecated in version 0.20 and will be removed in 0.22. Import impute.SimpleImputer from sklearn instead.
#   warnings.warn(msg, category=DeprecationWarning)
# 100
# 100    IBRD only
# Name: Country Name, dtype: object
# 58.504652725254424
# 58.51472233880669
# 58.52479195235895
# 58.53486156591122
# 58.54493117946349
# 58.55500079301575
# 58.565070406568026
# 101
# (47, 1)
# (47, 1)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:66: DeprecationWarning: Class Imputer is deprecated; Imputer was deprecated in version 0.20 and will be removed in 0.22. Import impute.SimpleImputer from sklearn instead.
#   warnings.warn(msg, category=DeprecationWarning)
# 101
# 101    IDA & IBRD total
# Name: Country Name, dtype: object
# 93.2658236313174
# 93.28289921236066
# 93.2999747934039
# 93.31705037444716
# 93.3341259554904
# 93.35120153653367
# 93.36827711757692
# 102
# (47, 1)
# (47, 1)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:66: DeprecationWarning: Class Imputer is deprecated; Imputer was deprecated in version 0.20 and will be removed in 0.22. Import impute.SimpleImputer from sklearn instead.
#   warnings.warn(msg, category=DeprecationWarning)
# 102
# 102    IDA total
# Name: Country Name, dtype: object
# 94.46993221940659
# 94.80600133444682
# 95.14207044948705
# 95.47813956452728
# 95.8142086795674
# 96.15027779460763
# 96.48634690964786
# 103
# (47, 1)
# (47, 1)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:66: DeprecationWarning: Class Imputer is deprecated; Imputer was deprecated in version 0.20 and will be removed in 0.22. Import impute.SimpleImputer from sklearn instead.
#   warnings.warn(msg, category=DeprecationWarning)
# 103
# 103    IDA blend
# Name: Country Name, dtype: object
# 82.41277579221924
# 83.35753758435044
# 84.30229937648141
# 85.24706116861262
# 86.1918229607436
# 87.1365847528748
# 88.08134654500577
# 104
# (47, 1)
# (47, 1)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:66: DeprecationWarning: Class Imputer is deprecated; Imputer was deprecated in version 0.20 and will be removed in 0.22. Import impute.SimpleImputer from sklearn instead.
#   warnings.warn(msg, category=DeprecationWarning)
# 104
# 104    Indonesia
# Name: Country Name, dtype: object
# 99.2524903630446
# 99.25204251773852
# 99.25159467243243
# 99.25114682712635
# 99.25069898182026
# 99.25025113651418
# 99.2498032912081
# 105
# (47, 1)
# (47, 1)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:66: DeprecationWarning: Class Imputer is deprecated; Imputer was deprecated in version 0.20 and will be removed in 0.22. Import impute.SimpleImputer from sklearn instead.
#   warnings.warn(msg, category=DeprecationWarning)
# 105
# 105    IDA only
# Name: Country Name, dtype: object
# 70.72047391305318
# 71.46170636168449
# 72.2029388103158
# 72.94417125894711
# 73.68540370757842
# 74.42663615620972
# 75.16786860484103
# 106
# (47, 1)
# (47, 1)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:66: DeprecationWarning: Class Imputer is deprecated; Imputer was deprecated in version 0.20 and will be removed in 0.22. Import impute.SimpleImputer from sklearn instead.
#   warnings.warn(msg, category=DeprecationWarning)
# 106
# 106    Isle of Man
# Name: Country Name, dtype: object
# 61.60850468114825
# 61.775327442387834
# 61.942150203627364
# 62.10897296486695
# 62.27579572610654
# 62.442618487346124
# 62.60944124858571
# 107
# (47, 1)
# (47, 1)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:66: DeprecationWarning: Class Imputer is deprecated; Imputer was deprecated in version 0.20 and will be removed in 0.22. Import impute.SimpleImputer from sklearn instead.
#   warnings.warn(msg, category=DeprecationWarning)
# 107
# 107    India
# Name: Country Name, dtype: object
# 76.36110955948891
# 76.4424115175353
# 76.52371347558167
# 76.60501543362807
# 76.68631739167444
# 76.76761934972083
# 76.8489213077672
# 108
# (47, 1)
# (47, 1)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:66: DeprecationWarning: Class Imputer is deprecated; Imputer was deprecated in version 0.20 and will be removed in 0.22. Import impute.SimpleImputer from sklearn instead.
#   warnings.warn(msg, category=DeprecationWarning)
# 108
# 108    Not classified
# Name: Country Name, dtype: object
# 93.57877394069004
# 93.83570499576234
# 94.09263605083464
# 94.34956710590706
# 94.60649816097936
# 94.86342921605166
# 95.12036027112407
# 109
# (47, 1)
# (47, 1)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:66: DeprecationWarning: Class Imputer is deprecated; Imputer was deprecated in version 0.20 and will be removed in 0.22. Import impute.SimpleImputer from sklearn instead.
#   warnings.warn(msg, category=DeprecationWarning)
# 109
# 109    Ireland
# Name: Country Name, dtype: object
# 71.32812229232916
# 71.36401722076931
# 71.39991214920946
# 71.4358070776496
# 71.47170200608974
# 71.5075969345299
# 71.54349186297004
# 110
# (47, 1)
# (47, 1)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:66: DeprecationWarning: Class Imputer is deprecated; Imputer was deprecated in version 0.20 and will be removed in 0.22. Import impute.SimpleImputer from sklearn instead.
#   warnings.warn(msg, category=DeprecationWarning)
# 110
# 110    Iran, Islamic Rep.
# Name: Country Name, dtype: object
# 70.12154565070777
# 70.15743901175581
# 70.19333237280384
# 70.22922573385188
# 70.2651190948999
# 70.30101245594794
# 70.33690581699597
# 111
# (47, 1)
# (47, 1)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:66: DeprecationWarning: Class Imputer is deprecated; Imputer was deprecated in version 0.20 and will be removed in 0.22. Import impute.SimpleImputer from sklearn instead.
#   warnings.warn(msg, category=DeprecationWarning)
# 111
# 111    Iraq
# Name: Country Name, dtype: object
# 98.01430704595327
# 98.56242711254549
# 99.11054717913748
# 99.6586672457297
# 100.20678731232192
# 100.75490737891391
# 101.30302744550613
# 112
# (47, 1)
# (47, 1)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:66: DeprecationWarning: Class Imputer is deprecated; Imputer was deprecated in version 0.20 and will be removed in 0.22. Import impute.SimpleImputer from sklearn instead.
#   warnings.warn(msg, category=DeprecationWarning)
# 112
# 112    Iceland
# Name: Country Name, dtype: object
# 98.41309989019145
# 98.44042582919417
# 98.4677517681969
# 98.49507770719964
# 98.52240364620236
# 98.54972958520509
# 98.57705552420782
# 113
# (47, 1)
# (47, 1)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:66: DeprecationWarning: Class Imputer is deprecated; Imputer was deprecated in version 0.20 and will be removed in 0.22. Import impute.SimpleImputer from sklearn instead.
#   warnings.warn(msg, category=DeprecationWarning)
# 113
# 113    Israel
# Name: Country Name, dtype: object
# 99.76091054209067
# 99.76271189801112
# 99.76451325393157
# 99.766314609852
# 99.76811596577245
# 99.7699173216929
# 99.77171867761334
# 114
# (47, 1)
# (47, 1)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:66: DeprecationWarning: Class Imputer is deprecated; Imputer was deprecated in version 0.20 and will be removed in 0.22. Import impute.SimpleImputer from sklearn instead.
#   warnings.warn(msg, category=DeprecationWarning)
# 114
# 114    Italy
# Name: Country Name, dtype: object
# 94.3261150937192
# 94.36727385105739
# 94.40843260839559
# 94.44959136573378
# 94.49075012307198
# 94.53190888041017
# 94.57306763774835
# 115
# (47, 1)
# (47, 1)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:66: DeprecationWarning: Class Imputer is deprecated; Imputer was deprecated in version 0.20 and will be removed in 0.22. Import impute.SimpleImputer from sklearn instead.
#   warnings.warn(msg, category=DeprecationWarning)
# 115
# 115    Jamaica
# Name: Country Name, dtype: object
# 90.83412914734207
# 90.86626195054282
# 90.89839475374356
# 90.93052755694431
# 90.96266036014507
# 90.99479316334582
# 91.02692596654656
# 116
# (47, 1)
# (47, 1)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:66: DeprecationWarning: Class Imputer is deprecated; Imputer was deprecated in version 0.20 and will be removed in 0.22. Import impute.SimpleImputer from sklearn instead.
#   warnings.warn(msg, category=DeprecationWarning)
# 116
# 116    Jordan
# Name: Country Name, dtype: object
# 75.17142044424963
# 75.30129969995136
# 75.43117895565308
# 75.56105821135486
# 75.69093746705659
# 75.82081672275831
# 75.95069597846003
# 117
# (47, 1)
# (47, 1)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:66: DeprecationWarning: Class Imputer is deprecated; Imputer was deprecated in version 0.20 and will be removed in 0.22. Import impute.SimpleImputer from sklearn instead.
#   warnings.warn(msg, category=DeprecationWarning)
# 117
# 117    Japan
# Name: Country Name, dtype: object
# 87.14345755325849
# 87.55141907510631
# 87.95938059695413
# 88.36734211880196
# 88.77530364064978
# 89.1832651624976
# 89.59122668434543
# 118
# (47, 1)
# (47, 1)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:66: DeprecationWarning: Class Imputer is deprecated; Imputer was deprecated in version 0.20 and will be removed in 0.22. Import impute.SimpleImputer from sklearn instead.
#   warnings.warn(msg, category=DeprecationWarning)
# 118
# 118    Kazakhstan
# Name: Country Name, dtype: object
# 91.03666349990694
# 91.09869896878531
# 91.16073443766368
# 91.22276990654204
# 91.2848053754204
# 91.34684084429877
# 91.40887631317713
# 119
# (47, 1)
# (47, 1)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:66: DeprecationWarning: Class Imputer is deprecated; Imputer was deprecated in version 0.20 and will be removed in 0.22. Import impute.SimpleImputer from sklearn instead.
#   warnings.warn(msg, category=DeprecationWarning)
# 119
# 119    Kenya
# Name: Country Name, dtype: object
# 73.23258247363425
# 73.27468178916234
# 73.31678110469042
# 73.3588804202185
# 73.40097973574659
# 73.44307905127467
# 73.48517836680274

# %%
display(df3.columns)
display(len(p2019))
df3['2019'] = p2019
df3['2020'] = p2020
df3['2021'] = p2021
df3['2022'] = p2022
df3['2023'] = p2023
df3['2024'] = p2024
df3['2025'] = p2025
display(df3.columns)
# Out:
# Index(['1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968',
#        '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977',
#        '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986',
#        '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995',
#        '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004',
#        '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
#        '2014', '2015', '2016', '2017', '2018', '2019', 'Unnamed: 64'],
#       dtype='object')
# 120
# Index(['1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968',
#        '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977',
#        '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986',
#        '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995',
#        '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004',
#        '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
#        '2014', '2015', '2016', '2017', '2018', '2019', 'Unnamed: 64', '2020',
#        '2021', '2022', '2023', '2024', '2025'],
#       dtype='object')

# %%
df3 = df3.drop(columns=['Unnamed: 64'])
display(df3)
# Out:
#      1960  1961  1962  1963  ...       2022       2023       2024       2025
# 3     NaN   NaN   NaN   NaN  ...  97.365064  97.364621  97.364179  97.363737
# 5     NaN   NaN   NaN   NaN  ...  76.435108  76.957469  77.479830  78.002191
# 7     NaN   NaN   NaN   NaN  ...  98.894825  98.918218  98.941611  98.965004
# 13    NaN   NaN   NaN   NaN  ...  99.715816  99.717321  99.718827  99.720333
# 14    NaN   NaN   NaN   NaN  ...  53.178676  53.313528  53.448380  53.583232
# ..    ...   ...   ...   ...  ...        ...        ...        ...        ...
# 255   NaN   NaN   NaN   NaN  ...  90.930528  90.962660  90.994793  91.026926
# 256   NaN   NaN   NaN   NaN  ...  75.561058  75.690937  75.820817  75.950696
# 257   NaN   NaN   NaN   NaN  ...  88.367342  88.775304  89.183265  89.591227
# 261   NaN   NaN   NaN   NaN  ...  91.222770  91.284805  91.346841  91.408876
# 262   NaN   NaN   NaN   NaN  ...  73.358880  73.400980  73.443079  73.485178
#
# [120 rows x 66 columns]

# %%
# Save To CSV
df3.to_csv('literacyPredicted.csv')

# %%
import matplotlib.pyplot as plt

def plotRatePerCountryImputed(row):
    x = np.arange(1960, 2026)
    y = df3.iloc[row].to_numpy()
    y1 = y.reshape(-1,1)
    imputer = Imputer()
    y_imputed = imputer.fit_transform(y1)
    display(x.shape)
    display(y_imputed.shape)
    plt.plot(x,y_imputed)
    plt.title("Literacy Rate Over years")
    plt.xlabel("Years")
    plt.ylabel("Literacy Rate")
    plt.legend()
    #plt.savefig('RatePerCountry.png', dpi=fig.dpi, bbox_inches='tight', pad_inches=0.5)
    plt.show()
    

def plotRatePerCountryEmpty(row):
    x = np.arange(1960, 2026)
    y = df3.iloc[row].to_numpy()
    y1 = y.reshape(-1,1)
    display(x.shape)
    display(y1.shape)
    plt.plot(x,y1)
    plt.title("Literacy Rate Over years")
    plt.xlabel("Years")
    plt.ylabel("Literacy Rate")
    plt.legend()
    #plt.savefig('RatePerCountry.png', dpi=fig.dpi, bbox_inches='tight', pad_inches=0.5)
    plt.show()

# %%
plotRatePerCountryEmpty(117)
plotRatePerCountryImputed(117)
# Out:
# (66,)
# (66, 1)
# No handles with labels found to put in legend.
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:66: DeprecationWarning: Class Imputer is deprecated; Imputer was deprecated in version 0.20 and will be removed in 0.22. Import impute.SimpleImputer from sklearn instead.
#   warnings.warn(msg, category=DeprecationWarning)
# (66,)
# (66, 1)
# No handles with labels found to put in legend.

# %%
plotRatePerCountryEmpty(17)
plotRatePerCountryImputed(17)
# Out:
# (66,)
# (66, 1)
# No handles with labels found to put in legend.
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:66: DeprecationWarning: Class Imputer is deprecated; Imputer was deprecated in version 0.20 and will be removed in 0.22. Import impute.SimpleImputer from sklearn instead.
#   warnings.warn(msg, category=DeprecationWarning)
# (66,)
# (66, 1)
# No handles with labels found to put in legend.

# %%
df4 = df
display(df4.shape)
df4.dropna(axis=0, how='all', thresh=9, inplace=True)
# display(df4)
display(df4.shape)
year = '2019'
fig_size = plt.rcParams["figure.figsize"]
fig_size[0] = 18
fig_size[1] = 13
plt.rcParams["figure.figsize"] = fig_size

def plotYearBar(year):
    x = df4['Country Name']
    # display(x)
    y = df3[str(year)]
    # display(y)
    plt.bar(x,y)
    plt.title("Literacy Rate for year" + str(year))
    plt.xlabel("Literacy Rate Per Country")
    plt.ylabel("Literacy Rate")
    plt.legend()
    plt.xticks(rotation=90)
    #plt.savefig('RatePerYear.png', dpi=fig.dpi, bbox_inches='tight', pad_inches=0.5)
    plt.show()
# Out:
# (264, 65)
# (120, 65)

# %%
plotYearBar(2019)
# Out:
# No handles with labels found to put in legend.

# %%
plotYearBar(2020)
# Out:
# No handles with labels found to put in legend.

# %%
plotYearBar(2000)
# Out:
# No handles with labels found to put in legend.

# %%
plotYearBar(1996)
# Out:
# No handles with labels found to put in legend.
